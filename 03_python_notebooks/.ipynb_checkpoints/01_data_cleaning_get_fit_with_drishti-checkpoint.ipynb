# %%
print("Jupyter is working for Get Fit with Drishti project!")
# Out:
# Jupyter is working for Get Fit with Drishti project!

# %%
ls
# Out:
# 01_data_cleaning_get_fit_with_drishti.ipynb

# %%
print("Jupyter is working for Get Fit with Drishti project!")
# Out:
# Jupyter is working for Get Fit with Drishti project!
